# %% [markdown]
# ### Utility function check

# %%
from functions import *

# %%
fr_num=900

# %%
showImage(fr_num, all_path)

# %%
showData(fr_num)
# Out:
#            img_no  ear_r_x  ear_r_y  ear_l_x  ear_l_y  eye_r_x  eye_r_y  \
# 899  img_0900.jpg    208.0    107.0    316.0    101.0    244.0    171.0
#
#      eye_l_x  eye_l_y  nose_x  nose_y
# 899    314.0    180.0   275.0   223.0

# %%
img, mark = showMarks(fr_num, data)

# %%
panCheck(img, mark)
tiltCheck(img, mark)
# Out:
# right side clear
# left side clear
# |R_eye---(0.44)---N---(0.56)---L_eye|
# front face in terms of x-coords
#
#         --Ear center--
#               |
#             0.60
#               |
#          -Eye center-
#               |
#             0.40
#               |
#            --Nose--
#
# front face in terms of y-coords

# %%
data[300:400]
# Out:
#            img_no  ear_r_x  ear_r_y  ear_l_x  ear_l_y  eye_r_x  eye_r_y  \
# 300  img_0301.jpg    253.0     44.0    317.0     73.0    333.0    153.0
# 301  img_0302.jpg      NaN      NaN    316.0     74.0    333.0    153.0
# 302  img_0303.jpg    252.0     42.0    315.0     73.0    329.0    154.0
# 303  img_0304.jpg    249.0     44.0    314.0     75.0    327.0    160.0
# 304  img_0305.jpg    246.0     47.0    311.0     75.0    324.0    159.0
# ..            ...      ...      ...      ...      ...      ...      ...
# 395  img_0396.jpg      NaN      NaN     56.0    123.0      NaN      NaN
# 396  img_0397.jpg    269.0     90.0    238.0     89.0    306.0    208.0
# 397  img_0398.jpg    269.0     81.0    238.0     87.0    306.0    211.0
# 398  img_0399.jpg    271.0     80.0    239.0     89.0    304.0    209.0
# 399  img_0400.jpg    273.0     85.0    232.0     91.0    296.0    214.0
#
#      eye_l_x  eye_l_y  nose_x  nose_y
# 300      NaN      NaN   375.0   242.0
# 301      NaN      NaN   373.0   245.0
# 302      NaN      NaN   371.0   249.0
# 303      NaN      NaN   362.0   252.0
# 304      NaN      NaN   356.0   251.0
# ..       ...      ...     ...     ...
# 395     54.0    203.0    47.0   254.0
# 396      NaN      NaN   312.0   291.0
# 397      NaN      NaN   312.0   293.0
# 398      NaN      NaN   309.0   291.0
# 399      NaN      NaN   300.0   291.0
#
# [100 rows x 11 columns]

# %%
showImage(fr_num=30, all_path=all_path)

# %%
fr_num=301

# %%
showImage(fr_num, all_path)

# %%
df=data.iloc[[fr_num-1]]
df
# Out:
#            img_no  ear_r_x  ear_r_y  ear_l_x  ear_l_y  eye_r_x  eye_r_y  \
# 300  img_0301.jpg    253.0     44.0    317.0     73.0    333.0    153.0
#
#      eye_l_x  eye_l_y  nose_x  nose_y
# 300      NaN      NaN   375.0   242.0

# %%
df.isnull().values.any()
# Out:
# True

# %%
df["ear_l_x"].item()-df["ear_r_x"].item()
# Out:
# 64.0

# %%
data["eye_l_y"].isnull().sum()
# Out:
# 914

# %%
data["ear_l_y"].isnull().sum()
# Out:
# 129

# %%
df.isnull()['ear_r_x'].item()&df.notnull()['ear_l_x']&df.notnull()['ear_l_x']
# Out:
# 301    True
# Name: ear_l_x, dtype: bool

# %%
def panClassify(fr_num, data):
    """
    This function classifies the pose according to the approx. pan angle
    If there is no match, it shows the target image.
    """ 
    
    # retrieve the data strip
    df=data.iloc[[fr_num-1]]
    # case 1: if there exists at least one NaN in the data
    if df.isnull().values.any():
    
        # remove when there is no nose pose info       
        if df.isnull()['nose_x'].item():
            pass

        # case 1-1: head turned to the right approx. over 45 degrees
        elif df.isnull()['eye_r_x'].item()&df.notnull()['ear_r_x']&df.notnull()['ear_l_x']:
            # case 1-1-1: approx. 45 to 90 
            if df['ear_l_x'].item()-df['ear_r_x'].item() > 0:
                print("turned to the right (approx. 45 to 90 degrees)")
            # case 1-1-2: approx. over 90  # ref. frame 30
            else:
                print("turned to the right (approx. over 90 degrees)")

        # case 1-2: head turned to the left approx. over 45 degrees
        elif df.isnull()['eye_l_x'].item()&df.notnull()['ear_r_x']&df.notnull()['ear_l_x']:
                # case 1-2-1: approx. 45 to 90
            if df['ear_l_x'].item()-df['ear_r_x'].item() > 0:
                 print("turned to the left (approx. 45 to 90 degrees)")
            else:
                 print("turned to the left (approx. over 90 degrees)")

        else:    
            showImage(fr_num, all_path)
#       ----  
    
    
    
    else: 
        img, mark = showMarks(fr_num, data)
        ear_rx, ear_ry = mark[0]
        ear_lx, ear_ly = mark[1]
        ear_cx, ear_cy = mark[2]
        eye_rx, eye_ry = mark[3]
        eye_lx, eye_ly = mark[4]
        eye_cx, eye_cy = mark[5]
        n_x, n_y = mark[6]
        
        if
        
        # initial check
        if ear_rx < eye_rx & eye_rx < n_x:
            print('right side clear')
        if ear_lx > eye_lx & eye_lx > n_x:
            print('left side clear')
         # Hypothesis 1: critical part is the relation between the nose and eyes
        hori_eyes=abs(eye_lx-eye_rx) # distance between the eyes (horizontal)
        n_r_dev_raw=abs(eye_rx-n_x)
        n_l_dev_raw=abs(eye_lx-n_x)
        assert n_r_dev_raw+n_l_dev_raw == hori_eyes
        # how much the nose deviates: 
        n_r_dev=n_r_dev_raw/hori_eyes #if smaller than 0.5 -> turning to the right
        n_l_dev=n_l_dev_raw/hori_eyes # if smaller than 0.5 -> turning to the left
#         print(f'|R_eye---{n_r_dev}---N---{n_l_dev}---L_eye|')
        print('|R_eye---({:.2f})---N---({:.2f})---L_eye|'.format(n_r_dev, n_l_dev))
        
        plt.imshow(img)
        plt.axis('off')
        
        # define the front face when n_r_dev and n_l_dev is larger than 0.25 
        # to be a front face, those numbers should be between 0.5 w.r.t. the center
        if (n_r_dev >0.25) & (n_l_dev>0.25):
            print('front face in terms of x-coords') # (1)
        elif n_r_dev >0.25:
            print('turning to the left') # (2)
        else:
            print('turning to the right') #(3)

# %%
# import test_for_convert as fcts

# %%
# from test_for_convert import *

# %%
import glob
import os
import re #regex library
from platform import python_version

import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from PIL import Image
import cv2

# %%
all_path = []
for path in glob.glob("../data_all/mouse_pos/*.jpg"):
    all_path.append(path)
#     print(path)
len(all_path)
# Out:
# 4555

# %%
data = pd.read_csv("../data_all/mouse_body_pos.csv")
data.head()
# Out:
#          img_no  ear_r_x  ear_r_y  ear_l_x  ear_l_y  eye_r_x  eye_r_y  \
# 0  img_0001.jpg    265.0     85.0    382.0     95.0    280.0    198.0
# 1  img_0002.jpg    248.0      7.0    286.0     24.0      NaN      NaN
# 2  img_0003.jpg    265.0     85.0    381.0     96.0    276.0    197.0
# 3  img_0004.jpg    156.0     49.0      NaN      NaN    215.0     73.0
# 4  img_0005.jpg    170.0     99.0    230.0     99.0    192.0    143.0
#
#    eye_l_x  eye_l_y  nose_x  nose_y
# 0    342.0    199.0   296.0   276.0
# 1    206.0     42.0   124.0    41.0
# 2    338.0    199.0   291.0   276.0
# 3      NaN      NaN   279.0    83.0
# 4    234.0    147.0   227.0   183.0

# %%
# function 1

def pathSorting(all_path):
    fnum_str_list=[]
    # read the file and sort by numbers
    for path in all_path:    
        split_path=os.path.split(path)
        fname=split_path[1]
        fnum_included_str = re.findall(r'[0-9]+', fname)
        fnum_str = fnum_included_str[0]
        fnum_str_list.append(fnum_str)
        fnum_str_list.sort()
    sorted_path = [os.path.join(split_path[0], "img_"+fnum+".jpg") for fnum in fnum_str_list]
    return sorted_path

# %%
pathSorting(all_path)
# Out:
# ['../data_all/mouse_pos/img_0001.jpg',
#  '../data_all/mouse_pos/img_0002.jpg',
#  '../data_all/mouse_pos/img_0003.jpg',
#  '../data_all/mouse_pos/img_0004.jpg',
#  '../data_all/mouse_pos/img_0005.jpg',
#  '../data_all/mouse_pos/img_0006.jpg',
#  '../data_all/mouse_pos/img_0007.jpg',
#  '../data_all/mouse_pos/img_0008.jpg',
#  '../data_all/mouse_pos/img_0009.jpg',
#  '../data_all/mouse_pos/img_0010.jpg',
#  '../data_all/mouse_pos/img_0011.jpg',
#  '../data_all/mouse_pos/img_0012.jpg',
#  '../data_all/mouse_pos/img_0013.jpg',
#  '../data_all/mouse_pos/img_0014.jpg',
#  '../data_all/mouse_pos/img_0015.jpg',
#  '../data_all/mouse_pos/img_0016.jpg',
#  '../data_all/mouse_pos/img_0017.jpg',
#  '../data_all/mouse_pos/img_0018.jpg',
#  '../data_all/mouse_pos/img_0019.jpg',
#  '../data_all/mouse_pos/img_0020.jpg',
#  '../data_all/mouse_pos/img_0021.jpg',
#  '../data_all/mouse_pos/img_0022.jpg',
#  '../data_all/mouse_pos/img_0023.jpg',
#  '../data_all/mouse_pos/img_0024.jpg',
#  '../data_all/mouse_pos/img_0025.jpg',
#  '../data_all/mouse_pos/img_0026.jpg',
#  '../data_all/mouse_pos/img_0027.jpg',
#  '../data_all/mouse_pos/img_0028.jpg',
#  '../data_all/mouse_pos/img_0029.jpg',
#  '../data_all/mouse_pos/img_0030.jpg',
#  '../data_all/mouse_pos/img_0031.jpg',
#  '../data_all/mouse_pos/img_0032.jpg',
#  '../data_all/mouse_pos/img_0033.jpg',
#  '../data_all/mouse_pos/img_0034.jpg',
#  '../data_all/mouse_pos/img_0035.jpg',
#  '../data_all/mouse_pos/img_0036.jpg',
#  '../data_all/mouse_pos/img_0037.jpg',
#  '../data_all/mouse_pos/img_0038.jpg',
#  '../data_all/mouse_pos/img_0039.jpg',
#  '../data_all/mouse_pos/img_0040.jpg',
#  '../data_all/mouse_pos/img_0041.jpg',
#  '../data_all/mouse_pos/img_0042.jpg',
#  '../data_all/mouse_pos/img_0043.jpg',
#  '../data_all/mouse_pos/img_0044.jpg',
#  '../data_all/mouse_pos/img_0045.jpg',
#  '../data_all/mouse_pos/img_0046.jpg',
#  '../data_all/mouse_pos/img_0047.jpg',
#  '../data_all/mouse_pos/img_0048.jpg',
#  '../data_all/mouse_pos/img_0049.jpg',
#  '../data_all/mouse_pos/img_0050.jpg',
#  '../data_all/mouse_pos/img_0051.jpg',
#  '../data_all/mouse_pos/img_0052.jpg',
#  '../data_all/mouse_pos/img_0053.jpg',
#  '../data_all/mouse_pos/img_0054.jpg',
#  '../data_all/mouse_pos/img_0055.jpg',
#  '../data_all/mouse_pos/img_0056.jpg',
#  '../data_all/mouse_pos/img_0057.jpg',
#  '../data_all/mouse_pos/img_0058.jpg',
#  '../data_all/mouse_pos/img_0059.jpg',
#  '../data_all/mouse_pos/img_0060.jpg',
#  '../data_all/mouse_pos/img_0061.jpg',
#  '../data_all/mouse_pos/img_0062.jpg',
#  '../data_all/mouse_pos/img_0063.jpg',
#  '../data_all/mouse_pos/img_0064.jpg',
#  '../data_all/mouse_pos/img_0065.jpg',
#  '../data_all/mouse_pos/img_0066.jpg',
#  '../data_all/mouse_pos/img_0067.jpg',
#  '../data_all/mouse_pos/img_0068.jpg',
#  '../data_all/mouse_pos/img_0069.jpg',
#  '../data_all/mouse_pos/img_0070.jpg',
#  '../data_all/mouse_pos/img_0071.jpg',
#  '../data_all/mouse_pos/img_0072.jpg',
#  '../data_all/mouse_pos/img_0073.jpg',
#  '../data_all/mouse_pos/img_0074.jpg',
#  '../data_all/mouse_pos/img_0075.jpg',
#  '../data_all/mouse_pos/img_0076.jpg',
#  '../data_all/mouse_pos/img_0077.jpg',
#  '../data_all/mouse_pos/img_0078.jpg',
#  '../data_all/mouse_pos/img_0079.jpg',
#  '../data_all/mouse_pos/img_0080.jpg',
#  '../data_all/mouse_pos/img_0081.jpg',
#  '../data_all/mouse_pos/img_0082.jpg',
#  '../data_all/mouse_pos/img_0083.jpg',
#  '../data_all/mouse_pos/img_0084.jpg',
#  '../data_all/mouse_pos/img_0085.jpg',
#  '../data_all/mouse_pos/img_0086.jpg',
#  '../data_all/mouse_pos/img_0087.jpg',
#  '../data_all/mouse_pos/img_0088.jpg',
#  '../data_all/mouse_pos/img_0089.jpg',
#  '../data_all/mouse_pos/img_0090.jpg',
#  '../data_all/mouse_pos/img_0091.jpg',
#  '../data_all/mouse_pos/img_0092.jpg',
#  '../data_all/mouse_pos/img_0093.jpg',
#  '../data_all/mouse_pos/img_0094.jpg',
#  '../data_all/mouse_pos/img_0095.jpg',
#  '../data_all/mouse_pos/img_0096.jpg',
#  '../data_all/mouse_pos/img_0097.jpg',
#  '../data_all/mouse_pos/img_0098.jpg',
#  '../data_all/mouse_pos/img_0099.jpg',
#  '../data_all/mouse_pos/img_0100.jpg',
#  '../data_all/mouse_pos/img_0101.jpg',
#  '../data_all/mouse_pos/img_0102.jpg',
#  '../data_all/mouse_pos/img_0103.jpg',
#  '../data_all/mouse_pos/img_0104.jpg',
#  '../data_all/mouse_pos/img_0105.jpg',
#  '../data_all/mouse_pos/img_0106.jpg',
#  '../data_all/mouse_pos/img_0107.jpg',
#  '../data_all/mouse_pos/img_0108.jpg',
#  '../data_all/mouse_pos/img_0109.jpg',
#  '../data_all/mouse_pos/img_0110.jpg',
#  '../data_all/mouse_pos/img_0111.jpg',
#  '../data_all/mouse_pos/img_0112.jpg',
#  '../data_all/mouse_pos/img_0113.jpg',
#  '../data_all/mouse_pos/img_0114.jpg',
#  '../data_all/mouse_pos/img_0115.jpg',
#  '../data_all/mouse_pos/img_0116.jpg',
#  '../data_all/mouse_pos/img_0117.jpg',
#  '../data_all/mouse_pos/img_0118.jpg',
#  '../data_all/mouse_pos/img_0119.jpg',
#  '../data_all/mouse_pos/img_0120.jpg',
#  '../data_all/mouse_pos/img_0121.jpg',
#  '../data_all/mouse_pos/img_0122.jpg',
#  '../data_all/mouse_pos/img_0123.jpg',
#  '../data_all/mouse_pos/img_0124.jpg',
#  '../data_all/mouse_pos/img_0125.jpg',
#  '../data_all/mouse_pos/img_0126.jpg',
#  '../data_all/mouse_pos/img_0127.jpg',
#  '../data_all/mouse_pos/img_0128.jpg',
#  '../data_all/mouse_pos/img_0129.jpg',
#  '../data_all/mouse_pos/img_0130.jpg',
#  '../data_all/mouse_pos/img_0131.jpg',
#  '../data_all/mouse_pos/img_0132.jpg',
#  '../data_all/mouse_pos/img_0133.jpg',
#  '../data_all/mouse_pos/img_0134.jpg',
#  '../data_all/mouse_pos/img_0135.jpg',
#  '../data_all/mouse_pos/img_0136.jpg',
#  '../data_all/mouse_pos/img_0137.jpg',
#  '../data_all/mouse_pos/img_0138.jpg',
#  '../data_all/mouse_pos/img_0139.jpg',
#  '../data_all/mouse_pos/img_0140.jpg',
#  '../data_all/mouse_pos/img_0141.jpg',
#  '../data_all/mouse_pos/img_0142.jpg',
#  '../data_all/mouse_pos/img_0143.jpg',
#  '../data_all/mouse_pos/img_0144.jpg',
#  '../data_all/mouse_pos/img_0145.jpg',
#  '../data_all/mouse_pos/img_0146.jpg',
#  '../data_all/mouse_pos/img_0147.jpg',
#  '../data_all/mouse_pos/img_0148.jpg',
#  '../data_all/mouse_pos/img_0149.jpg',
#  '../data_all/mouse_pos/img_0150.jpg',
#  '../data_all/mouse_pos/img_0151.jpg',
#  '../data_all/mouse_pos/img_0152.jpg',
#  '../data_all/mouse_pos/img_0153.jpg',
#  '../data_all/mouse_pos/img_0154.jpg',
#  '../data_all/mouse_pos/img_0155.jpg',
#  '../data_all/mouse_pos/img_0156.jpg',
#  '../data_all/mouse_pos/img_0157.jpg',
#  '../data_all/mouse_pos/img_0158.jpg',
#  '../data_all/mouse_pos/img_0159.jpg',
#  '../data_all/mouse_pos/img_0160.jpg',
#  '../data_all/mouse_pos/img_0161.jpg',
#  '../data_all/mouse_pos/img_0162.jpg',
#  '../data_all/mouse_pos/img_0163.jpg',
#  '../data_all/mouse_pos/img_0164.jpg',
#  '../data_all/mouse_pos/img_0165.jpg',
#  '../data_all/mouse_pos/img_0166.jpg',
#  '../data_all/mouse_pos/img_0167.jpg',
#  '../data_all/mouse_pos/img_0168.jpg',
#  '../data_all/mouse_pos/img_0169.jpg',
#  '../data_all/mouse_pos/img_0170.jpg',
#  '../data_all/mouse_pos/img_0171.jpg',
#  '../data_all/mouse_pos/img_0172.jpg',
#  '../data_all/mouse_pos/img_0173.jpg',
#  '../data_all/mouse_pos/img_0174.jpg',
#  '../data_all/mouse_pos/img_0175.jpg',
#  '../data_all/mouse_pos/img_0176.jpg',
#  '../data_all/mouse_pos/img_0177.jpg',
#  '../data_all/mouse_pos/img_0178.jpg',
#  '../data_all/mouse_pos/img_0179.jpg',
#  '../data_all/mouse_pos/img_0180.jpg',
#  '../data_all/mouse_pos/img_0181.jpg',
#  '../data_all/mouse_pos/img_0182.jpg',
#  '../data_all/mouse_pos/img_0183.jpg',
#  '../data_all/mouse_pos/img_0184.jpg',
#  '../data_all/mouse_pos/img_0185.jpg',
#  '../data_all/mouse_pos/img_0186.jpg',
#  '../data_all/mouse_pos/img_0187.jpg',
#  '../data_all/mouse_pos/img_0188.jpg',
#  '../data_all/mouse_pos/img_0189.jpg',
#  '../data_all/mouse_pos/img_0190.jpg',
#  '../data_all/mouse_pos/img_0191.jpg',
#  '../data_all/mouse_pos/img_0192.jpg',
#  '../data_all/mouse_pos/img_0193.jpg',
#  '../data_all/mouse_pos/img_0194.jpg',
#  '../data_all/mouse_pos/img_0195.jpg',
#  '../data_all/mouse_pos/img_0196.jpg',
#  '../data_all/mouse_pos/img_0197.jpg',
#  '../data_all/mouse_pos/img_0198.jpg',
#  '../data_all/mouse_pos/img_0199.jpg',
#  '../data_all/mouse_pos/img_0200.jpg',
#  '../data_all/mouse_pos/img_0201.jpg',
#  '../data_all/mouse_pos/img_0202.jpg',
#  '../data_all/mouse_pos/img_0203.jpg',
#  '../data_all/mouse_pos/img_0204.jpg',
#  '../data_all/mouse_pos/img_0205.jpg',
#  '../data_all/mouse_pos/img_0206.jpg',
#  '../data_all/mouse_pos/img_0207.jpg',
#  '../data_all/mouse_pos/img_0208.jpg',
#  '../data_all/mouse_pos/img_0209.jpg',
#  '../data_all/mouse_pos/img_0210.jpg',
#  '../data_all/mouse_pos/img_0211.jpg',
#  '../data_all/mouse_pos/img_0212.jpg',
#  '../data_all/mouse_pos/img_0213.jpg',
#  '../data_all/mouse_pos/img_0214.jpg',
#  '../data_all/mouse_pos/img_0215.jpg',
#  '../data_all/mouse_pos/img_0216.jpg',
#  '../data_all/mouse_pos/img_0217.jpg',
#  '../data_all/mouse_pos/img_0218.jpg',
#  '../data_all/mouse_pos/img_0219.jpg',
#  '../data_all/mouse_pos/img_0220.jpg',
#  '../data_all/mouse_pos/img_0221.jpg',
#  '../data_all/mouse_pos/img_0222.jpg',
#  '../data_all/mouse_pos/img_0223.jpg',
#  '../data_all/mouse_pos/img_0224.jpg',
#  '../data_all/mouse_pos/img_0225.jpg',
#  '../data_all/mouse_pos/img_0226.jpg',
#  '../data_all/mouse_pos/img_0227.jpg',
#  '../data_all/mouse_pos/img_0228.jpg',
#  '../data_all/mouse_pos/img_0229.jpg',
#  '../data_all/mouse_pos/img_0230.jpg',
#  '../data_all/mouse_pos/img_0231.jpg',
#  '../data_all/mouse_pos/img_0232.jpg',
#  '../data_all/mouse_pos/img_0233.jpg',
#  '../data_all/mouse_pos/img_0234.jpg',
#  '../data_all/mouse_pos/img_0235.jpg',
#  '../data_all/mouse_pos/img_0236.jpg',
#  '../data_all/mouse_pos/img_0237.jpg',
#  '../data_all/mouse_pos/img_0238.jpg',
#  '../data_all/mouse_pos/img_0239.jpg',
#  '../data_all/mouse_pos/img_0240.jpg',
#  '../data_all/mouse_pos/img_0241.jpg',
#  '../data_all/mouse_pos/img_0242.jpg',
#  '../data_all/mouse_pos/img_0243.jpg',
#  '../data_all/mouse_pos/img_0244.jpg',
#  '../data_all/mouse_pos/img_0245.jpg',
#  '../data_all/mouse_pos/img_0246.jpg',
#  '../data_all/mouse_pos/img_0247.jpg',
#  '../data_all/mouse_pos/img_0248.jpg',
#  '../data_all/mouse_pos/img_0249.jpg',
#  '../data_all/mouse_pos/img_0250.jpg',
#  '../data_all/mouse_pos/img_0251.jpg',
#  '../data_all/mouse_pos/img_0252.jpg',
#  '../data_all/mouse_pos/img_0253.jpg',
#  '../data_all/mouse_pos/img_0254.jpg',
#  '../data_all/mouse_pos/img_0255.jpg',
#  '../data_all/mouse_pos/img_0256.jpg',
#  '../data_all/mouse_pos/img_0257.jpg',
#  '../data_all/mouse_pos/img_0258.jpg',
#  '../data_all/mouse_pos/img_0259.jpg',
#  '../data_all/mouse_pos/img_0260.jpg',
#  '../data_all/mouse_pos/img_0261.jpg',
#  '../data_all/mouse_pos/img_0262.jpg',
#  '../data_all/mouse_pos/img_0263.jpg',
#  '../data_all/mouse_pos/img_0264.jpg',
#  '../data_all/mouse_pos/img_0265.jpg',
#  '../data_all/mouse_pos/img_0266.jpg',
#  '../data_all/mouse_pos/img_0267.jpg',
#  '../data_all/mouse_pos/img_0268.jpg',
#  '../data_all/mouse_pos/img_0269.jpg',
#  '../data_all/mouse_pos/img_0270.jpg',
#  '../data_all/mouse_pos/img_0271.jpg',
#  '../data_all/mouse_pos/img_0272.jpg',
#  '../data_all/mouse_pos/img_0273.jpg',
#  '../data_all/mouse_pos/img_0274.jpg',
#  '../data_all/mouse_pos/img_0275.jpg',
#  '../data_all/mouse_pos/img_0276.jpg',
#  '../data_all/mouse_pos/img_0277.jpg',
#  '../data_all/mouse_pos/img_0278.jpg',
#  '../data_all/mouse_pos/img_0279.jpg',
#  '../data_all/mouse_pos/img_0280.jpg',
#  '../data_all/mouse_pos/img_0281.jpg',
#  '../data_all/mouse_pos/img_0282.jpg',
#  '../data_all/mouse_pos/img_0283.jpg',
#  '../data_all/mouse_pos/img_0284.jpg',
#  '../data_all/mouse_pos/img_0285.jpg',
#  '../data_all/mouse_pos/img_0286.jpg',
#  '../data_all/mouse_pos/img_0287.jpg',
#  '../data_all/mouse_pos/img_0288.jpg',
#  '../data_all/mouse_pos/img_0289.jpg',
#  '../data_all/mouse_pos/img_0290.jpg',
#  '../data_all/mouse_pos/img_0291.jpg',
#  '../data_all/mouse_pos/img_0292.jpg',
#  '../data_all/mouse_pos/img_0293.jpg',
#  '../data_all/mouse_pos/img_0294.jpg',
#  '../data_all/mouse_pos/img_0295.jpg',
#  '../data_all/mouse_pos/img_0296.jpg',
#  '../data_all/mouse_pos/img_0297.jpg',
#  '../data_all/mouse_pos/img_0298.jpg',
#  '../data_all/mouse_pos/img_0299.jpg',
#  '../data_all/mouse_pos/img_0300.jpg',
#  '../data_all/mouse_pos/img_0301.jpg',
#  '../data_all/mouse_pos/img_0302.jpg',
#  '../data_all/mouse_pos/img_0303.jpg',
#  '../data_all/mouse_pos/img_0304.jpg',
#  '../data_all/mouse_pos/img_0305.jpg',
#  '../data_all/mouse_pos/img_0306.jpg',
#  '../data_all/mouse_pos/img_0307.jpg',
#  '../data_all/mouse_pos/img_0308.jpg',
#  '../data_all/mouse_pos/img_0309.jpg',
#  '../data_all/mouse_pos/img_0310.jpg',
#  '../data_all/mouse_pos/img_0311.jpg',
#  '../data_all/mouse_pos/img_0312.jpg',
#  '../data_all/mouse_pos/img_0313.jpg',
#  '../data_all/mouse_pos/img_0314.jpg',
#  '../data_all/mouse_pos/img_0315.jpg',
#  '../data_all/mouse_pos/img_0316.jpg',
#  '../data_all/mouse_pos/img_0317.jpg',
#  '../data_all/mouse_pos/img_0318.jpg',
#  '../data_all/mouse_pos/img_0319.jpg',
#  '../data_all/mouse_pos/img_0320.jpg',
#  '../data_all/mouse_pos/img_0321.jpg',
#  '../data_all/mouse_pos/img_0322.jpg',
#  '../data_all/mouse_pos/img_0323.jpg',
#  '../data_all/mouse_pos/img_0324.jpg',
#  '../data_all/mouse_pos/img_0325.jpg',
#  '../data_all/mouse_pos/img_0326.jpg',
#  '../data_all/mouse_pos/img_0327.jpg',
#  '../data_all/mouse_pos/img_0328.jpg',
#  '../data_all/mouse_pos/img_0329.jpg',
#  '../data_all/mouse_pos/img_0330.jpg',
#  '../data_all/mouse_pos/img_0331.jpg',
#  '../data_all/mouse_pos/img_0332.jpg',
#  '../data_all/mouse_pos/img_0333.jpg',
#  '../data_all/mouse_pos/img_0334.jpg',
#  '../data_all/mouse_pos/img_0335.jpg',
#  '../data_all/mouse_pos/img_0336.jpg',
#  '../data_all/mouse_pos/img_0337.jpg',
#  '../data_all/mouse_pos/img_0338.jpg',
#  '../data_all/mouse_pos/img_0339.jpg',
#  '../data_all/mouse_pos/img_0340.jpg',
#  '../data_all/mouse_pos/img_0341.jpg',
#  '../data_all/mouse_pos/img_0342.jpg',
#  '../data_all/mouse_pos/img_0343.jpg',
#  '../data_all/mouse_pos/img_0344.jpg',
#  '../data_all/mouse_pos/img_0345.jpg',
#  '../data_all/mouse_pos/img_0346.jpg',
#  '../data_all/mouse_pos/img_0347.jpg',
#  '../data_all/mouse_pos/img_0348.jpg',
#  '../data_all/mouse_pos/img_0349.jpg',
#  '../data_all/mouse_pos/img_0350.jpg',
#  '../data_all/mouse_pos/img_0351.jpg',
#  '../data_all/mouse_pos/img_0352.jpg',
#  '../data_all/mouse_pos/img_0353.jpg',
#  '../data_all/mouse_pos/img_0354.jpg',
#  '../data_all/mouse_pos/img_0355.jpg',
#  '../data_all/mouse_pos/img_0356.jpg',
#  '../data_all/mouse_pos/img_0357.jpg',
#  '../data_all/mouse_pos/img_0358.jpg',
#  '../data_all/mouse_pos/img_0359.jpg',
#  '../data_all/mouse_pos/img_0360.jpg',
#  '../data_all/mouse_pos/img_0361.jpg',
#  '../data_all/mouse_pos/img_0362.jpg',
#  '../data_all/mouse_pos/img_0363.jpg',
#  '../data_all/mouse_pos/img_0364.jpg',
#  '../data_all/mouse_pos/img_0365.jpg',
#  '../data_all/mouse_pos/img_0366.jpg',
#  '../data_all/mouse_pos/img_0367.jpg',
#  '../data_all/mouse_pos/img_0368.jpg',
#  '../data_all/mouse_pos/img_0369.jpg',
#  '../data_all/mouse_pos/img_0370.jpg',
#  '../data_all/mouse_pos/img_0371.jpg',
#  '../data_all/mouse_pos/img_0372.jpg',
#  '../data_all/mouse_pos/img_0373.jpg',
#  '../data_all/mouse_pos/img_0374.jpg',
#  '../data_all/mouse_pos/img_0375.jpg',
#  '../data_all/mouse_pos/img_0376.jpg',
#  '../data_all/mouse_pos/img_0377.jpg',
#  '../data_all/mouse_pos/img_0378.jpg',
#  '../data_all/mouse_pos/img_0379.jpg',
#  '../data_all/mouse_pos/img_0380.jpg',
#  '../data_all/mouse_pos/img_0381.jpg',
#  '../data_all/mouse_pos/img_0382.jpg',
#  '../data_all/mouse_pos/img_0383.jpg',
#  '../data_all/mouse_pos/img_0384.jpg',
#  '../data_all/mouse_pos/img_0385.jpg',
#  '../data_all/mouse_pos/img_0386.jpg',
#  '../data_all/mouse_pos/img_0387.jpg',
#  '../data_all/mouse_pos/img_0388.jpg',
#  '../data_all/mouse_pos/img_0389.jpg',
#  '../data_all/mouse_pos/img_0390.jpg',
#  '../data_all/mouse_pos/img_0391.jpg',
#  '../data_all/mouse_pos/img_0392.jpg',
#  '../data_all/mouse_pos/img_0393.jpg',
#  '../data_all/mouse_pos/img_0394.jpg',
#  '../data_all/mouse_pos/img_0395.jpg',
#  '../data_all/mouse_pos/img_0396.jpg',
#  '../data_all/mouse_pos/img_0397.jpg',
#  '../data_all/mouse_pos/img_0398.jpg',
#  '../data_all/mouse_pos/img_0399.jpg',
#  '../data_all/mouse_pos/img_0400.jpg',
#  '../data_all/mouse_pos/img_0401.jpg',
#  '../data_all/mouse_pos/img_0402.jpg',
#  '../data_all/mouse_pos/img_0403.jpg',
#  '../data_all/mouse_pos/img_0404.jpg',
#  '../data_all/mouse_pos/img_0405.jpg',
#  '../data_all/mouse_pos/img_0406.jpg',
#  '../data_all/mouse_pos/img_0407.jpg',
#  '../data_all/mouse_pos/img_0408.jpg',
#  '../data_all/mouse_pos/img_0409.jpg',
#  '../data_all/mouse_pos/img_0410.jpg',
#  '../data_all/mouse_pos/img_0411.jpg',
#  '../data_all/mouse_pos/img_0412.jpg',
#  '../data_all/mouse_pos/img_0413.jpg',
#  '../data_all/mouse_pos/img_0414.jpg',
#  '../data_all/mouse_pos/img_0415.jpg',
#  '../data_all/mouse_pos/img_0416.jpg',
#  '../data_all/mouse_pos/img_0417.jpg',
#  '../data_all/mouse_pos/img_0418.jpg',
#  '../data_all/mouse_pos/img_0419.jpg',
#  '../data_all/mouse_pos/img_0420.jpg',
#  '../data_all/mouse_pos/img_0421.jpg',
#  '../data_all/mouse_pos/img_0422.jpg',
#  '../data_all/mouse_pos/img_0423.jpg',
#  '../data_all/mouse_pos/img_0424.jpg',
#  '../data_all/mouse_pos/img_0425.jpg',
#  '../data_all/mouse_pos/img_0426.jpg',
#  '../data_all/mouse_pos/img_0427.jpg',
#  '../data_all/mouse_pos/img_0428.jpg',
#  '../data_all/mouse_pos/img_0429.jpg',
#  '../data_all/mouse_pos/img_0430.jpg',
#  '../data_all/mouse_pos/img_0431.jpg',
#  '../data_all/mouse_pos/img_0432.jpg',
#  '../data_all/mouse_pos/img_0433.jpg',
#  '../data_all/mouse_pos/img_0434.jpg',
#  '../data_all/mouse_pos/img_0435.jpg',
#  '../data_all/mouse_pos/img_0436.jpg',
#  '../data_all/mouse_pos/img_0437.jpg',
#  '../data_all/mouse_pos/img_0438.jpg',
#  '../data_all/mouse_pos/img_0439.jpg',
#  '../data_all/mouse_pos/img_0440.jpg',
#  '../data_all/mouse_pos/img_0441.jpg',
#  '../data_all/mouse_pos/img_0442.jpg',
#  '../data_all/mouse_pos/img_0443.jpg',
#  '../data_all/mouse_pos/img_0444.jpg',
#  '../data_all/mouse_pos/img_0445.jpg',
#  '../data_all/mouse_pos/img_0446.jpg',
#  '../data_all/mouse_pos/img_0447.jpg',
#  '../data_all/mouse_pos/img_0448.jpg',
#  '../data_all/mouse_pos/img_0449.jpg',
#  '../data_all/mouse_pos/img_0450.jpg',
#  '../data_all/mouse_pos/img_0451.jpg',
#  '../data_all/mouse_pos/img_0452.jpg',
#  '../data_all/mouse_pos/img_0453.jpg',
#  '../data_all/mouse_pos/img_0454.jpg',
#  '../data_all/mouse_pos/img_0455.jpg',
#  '../data_all/mouse_pos/img_0456.jpg',
#  '../data_all/mouse_pos/img_0457.jpg',
#  '../data_all/mouse_pos/img_0458.jpg',
#  '../data_all/mouse_pos/img_0459.jpg',
#  '../data_all/mouse_pos/img_0460.jpg',
#  '../data_all/mouse_pos/img_0461.jpg',
#  '../data_all/mouse_pos/img_0462.jpg',
#  '../data_all/mouse_pos/img_0463.jpg',
#  '../data_all/mouse_pos/img_0464.jpg',
#  '../data_all/mouse_pos/img_0465.jpg',
#  '../data_all/mouse_pos/img_0466.jpg',
#  '../data_all/mouse_pos/img_0467.jpg',
#  '../data_all/mouse_pos/img_0468.jpg',
#  '../data_all/mouse_pos/img_0469.jpg',
#  '../data_all/mouse_pos/img_0470.jpg',
#  '../data_all/mouse_pos/img_0471.jpg',
#  '../data_all/mouse_pos/img_0472.jpg',
#  '../data_all/mouse_pos/img_0473.jpg',
#  '../data_all/mouse_pos/img_0474.jpg',
#  '../data_all/mouse_pos/img_0475.jpg',
#  '../data_all/mouse_pos/img_0476.jpg',
#  '../data_all/mouse_pos/img_0477.jpg',
#  '../data_all/mouse_pos/img_0478.jpg',
#  '../data_all/mouse_pos/img_0479.jpg',
#  '../data_all/mouse_pos/img_0480.jpg',
#  '../data_all/mouse_pos/img_0481.jpg',
#  '../data_all/mouse_pos/img_0482.jpg',
#  '../data_all/mouse_pos/img_0483.jpg',
#  '../data_all/mouse_pos/img_0484.jpg',
#  '../data_all/mouse_pos/img_0485.jpg',
#  '../data_all/mouse_pos/img_0486.jpg',
#  '../data_all/mouse_pos/img_0487.jpg',
#  '../data_all/mouse_pos/img_0488.jpg',
#  '../data_all/mouse_pos/img_0489.jpg',
#  '../data_all/mouse_pos/img_0490.jpg',
#  '../data_all/mouse_pos/img_0491.jpg',
#  '../data_all/mouse_pos/img_0492.jpg',
#  '../data_all/mouse_pos/img_0493.jpg',
#  '../data_all/mouse_pos/img_0494.jpg',
#  '../data_all/mouse_pos/img_0495.jpg',
#  '../data_all/mouse_pos/img_0496.jpg',
#  '../data_all/mouse_pos/img_0497.jpg',
#  '../data_all/mouse_pos/img_0498.jpg',
#  '../data_all/mouse_pos/img_0499.jpg',
#  '../data_all/mouse_pos/img_0500.jpg',
#  '../data_all/mouse_pos/img_0501.jpg',
#  '../data_all/mouse_pos/img_0502.jpg',
#  '../data_all/mouse_pos/img_0503.jpg',
#  '../data_all/mouse_pos/img_0504.jpg',
#  '../data_all/mouse_pos/img_0505.jpg',
#  '../data_all/mouse_pos/img_0506.jpg',
#  '../data_all/mouse_pos/img_0507.jpg',
#  '../data_all/mouse_pos/img_0508.jpg',
#  '../data_all/mouse_pos/img_0509.jpg',
#  '../data_all/mouse_pos/img_0510.jpg',
#  '../data_all/mouse_pos/img_0511.jpg',
#  '../data_all/mouse_pos/img_0512.jpg',
#  '../data_all/mouse_pos/img_0513.jpg',
#  '../data_all/mouse_pos/img_0514.jpg',
#  '../data_all/mouse_pos/img_0515.jpg',
#  '../data_all/mouse_pos/img_0516.jpg',
#  '../data_all/mouse_pos/img_0517.jpg',
#  '../data_all/mouse_pos/img_0518.jpg',
#  '../data_all/mouse_pos/img_0519.jpg',
#  '../data_all/mouse_pos/img_0520.jpg',
#  '../data_all/mouse_pos/img_0521.jpg',
#  '../data_all/mouse_pos/img_0522.jpg',
#  '../data_all/mouse_pos/img_0523.jpg',
#  '../data_all/mouse_pos/img_0524.jpg',
#  '../data_all/mouse_pos/img_0525.jpg',
#  '../data_all/mouse_pos/img_0526.jpg',
#  '../data_all/mouse_pos/img_0527.jpg',
#  '../data_all/mouse_pos/img_0528.jpg',
#  '../data_all/mouse_pos/img_0529.jpg',
#  '../data_all/mouse_pos/img_0530.jpg',
#  '../data_all/mouse_pos/img_0531.jpg',
#  '../data_all/mouse_pos/img_0532.jpg',
#  '../data_all/mouse_pos/img_0533.jpg',
#  '../data_all/mouse_pos/img_0534.jpg',
#  '../data_all/mouse_pos/img_0535.jpg',
#  '../data_all/mouse_pos/img_0536.jpg',
#  '../data_all/mouse_pos/img_0537.jpg',
#  '../data_all/mouse_pos/img_0538.jpg',
#  '../data_all/mouse_pos/img_0539.jpg',
#  '../data_all/mouse_pos/img_0540.jpg',
#  '../data_all/mouse_pos/img_0541.jpg',
#  '../data_all/mouse_pos/img_0542.jpg',
#  '../data_all/mouse_pos/img_0543.jpg',
#  '../data_all/mouse_pos/img_0544.jpg',
#  '../data_all/mouse_pos/img_0545.jpg',
#  '../data_all/mouse_pos/img_0546.jpg',
#  '../data_all/mouse_pos/img_0547.jpg',
#  '../data_all/mouse_pos/img_0548.jpg',
#  '../data_all/mouse_pos/img_0549.jpg',
#  '../data_all/mouse_pos/img_0550.jpg',
#  '../data_all/mouse_pos/img_0551.jpg',
#  '../data_all/mouse_pos/img_0552.jpg',
#  '../data_all/mouse_pos/img_0553.jpg',
#  '../data_all/mouse_pos/img_0554.jpg',
#  '../data_all/mouse_pos/img_0555.jpg',
#  '../data_all/mouse_pos/img_0556.jpg',
#  '../data_all/mouse_pos/img_0557.jpg',
#  '../data_all/mouse_pos/img_0558.jpg',
#  '../data_all/mouse_pos/img_0559.jpg',
#  '../data_all/mouse_pos/img_0560.jpg',
#  '../data_all/mouse_pos/img_0561.jpg',
#  '../data_all/mouse_pos/img_0562.jpg',
#  '../data_all/mouse_pos/img_0563.jpg',
#  '../data_all/mouse_pos/img_0564.jpg',
#  '../data_all/mouse_pos/img_0565.jpg',
#  '../data_all/mouse_pos/img_0566.jpg',
#  '../data_all/mouse_pos/img_0567.jpg',
#  '../data_all/mouse_pos/img_0568.jpg',
#  '../data_all/mouse_pos/img_0569.jpg',
#  '../data_all/mouse_pos/img_0570.jpg',
#  '../data_all/mouse_pos/img_0571.jpg',
#  '../data_all/mouse_pos/img_0572.jpg',
#  '../data_all/mouse_pos/img_0573.jpg',
#  '../data_all/mouse_pos/img_0574.jpg',
#  '../data_all/mouse_pos/img_0575.jpg',
#  '../data_all/mouse_pos/img_0576.jpg',
#  '../data_all/mouse_pos/img_0577.jpg',
#  '../data_all/mouse_pos/img_0578.jpg',
#  '../data_all/mouse_pos/img_0579.jpg',
#  '../data_all/mouse_pos/img_0580.jpg',
#  '../data_all/mouse_pos/img_0581.jpg',
#  '../data_all/mouse_pos/img_0582.jpg',
#  '../data_all/mouse_pos/img_0583.jpg',
#  '../data_all/mouse_pos/img_0584.jpg',
#  '../data_all/mouse_pos/img_0585.jpg',
#  '../data_all/mouse_pos/img_0586.jpg',
#  '../data_all/mouse_pos/img_0587.jpg',
#  '../data_all/mouse_pos/img_0588.jpg',
#  '../data_all/mouse_pos/img_0589.jpg',
#  '../data_all/mouse_pos/img_0590.jpg',
#  '../data_all/mouse_pos/img_0591.jpg',
#  '../data_all/mouse_pos/img_0592.jpg',
#  '../data_all/mouse_pos/img_0593.jpg',
#  '../data_all/mouse_pos/img_0594.jpg',
#  '../data_all/mouse_pos/img_0595.jpg',
#  '../data_all/mouse_pos/img_0596.jpg',
#  '../data_all/mouse_pos/img_0597.jpg',
#  '../data_all/mouse_pos/img_0598.jpg',
#  '../data_all/mouse_pos/img_0599.jpg',
#  '../data_all/mouse_pos/img_0600.jpg',
#  '../data_all/mouse_pos/img_0601.jpg',
#  '../data_all/mouse_pos/img_0602.jpg',
#  '../data_all/mouse_pos/img_0603.jpg',
#  '../data_all/mouse_pos/img_0604.jpg',
#  '../data_all/mouse_pos/img_0605.jpg',
#  '../data_all/mouse_pos/img_0606.jpg',
#  '../data_all/mouse_pos/img_0607.jpg',
#  '../data_all/mouse_pos/img_0608.jpg',
#  '../data_all/mouse_pos/img_0609.jpg',
#  '../data_all/mouse_pos/img_0610.jpg',
#  '../data_all/mouse_pos/img_0611.jpg',
#  '../data_all/mouse_pos/img_0612.jpg',
#  '../data_all/mouse_pos/img_0613.jpg',
#  '../data_all/mouse_pos/img_0614.jpg',
#  '../data_all/mouse_pos/img_0615.jpg',
#  '../data_all/mouse_pos/img_0616.jpg',
#  '../data_all/mouse_pos/img_0617.jpg',
#  '../data_all/mouse_pos/img_0618.jpg',
#  '../data_all/mouse_pos/img_0619.jpg',
#  '../data_all/mouse_pos/img_0620.jpg',
#  '../data_all/mouse_pos/img_0621.jpg',
#  '../data_all/mouse_pos/img_0622.jpg',
#  '../data_all/mouse_pos/img_0623.jpg',
#  '../data_all/mouse_pos/img_0624.jpg',
#  '../data_all/mouse_pos/img_0625.jpg',
#  '../data_all/mouse_pos/img_0626.jpg',
#  '../data_all/mouse_pos/img_0627.jpg',
#  '../data_all/mouse_pos/img_0628.jpg',
#  '../data_all/mouse_pos/img_0629.jpg',
#  '../data_all/mouse_pos/img_0630.jpg',
#  '../data_all/mouse_pos/img_0631.jpg',
#  '../data_all/mouse_pos/img_0632.jpg',
#  '../data_all/mouse_pos/img_0633.jpg',
#  '../data_all/mouse_pos/img_0634.jpg',
#  '../data_all/mouse_pos/img_0635.jpg',
#  '../data_all/mouse_pos/img_0636.jpg',
#  '../data_all/mouse_pos/img_0637.jpg',
#  '../data_all/mouse_pos/img_0638.jpg',
#  '../data_all/mouse_pos/img_0639.jpg',
#  '../data_all/mouse_pos/img_0640.jpg',
#  '../data_all/mouse_pos/img_0641.jpg',
#  '../data_all/mouse_pos/img_0642.jpg',
#  '../data_all/mouse_pos/img_0643.jpg',
#  '../data_all/mouse_pos/img_0644.jpg',
#  '../data_all/mouse_pos/img_0645.jpg',
#  '../data_all/mouse_pos/img_0646.jpg',
#  '../data_all/mouse_pos/img_0647.jpg',
#  '../data_all/mouse_pos/img_0648.jpg',
#  '../data_all/mouse_pos/img_0649.jpg',
#  '../data_all/mouse_pos/img_0650.jpg',
#  '../data_all/mouse_pos/img_0651.jpg',
#  '../data_all/mouse_pos/img_0652.jpg',
#  '../data_all/mouse_pos/img_0653.jpg',
#  '../data_all/mouse_pos/img_0654.jpg',
#  '../data_all/mouse_pos/img_0655.jpg',
#  '../data_all/mouse_pos/img_0656.jpg',
#  '../data_all/mouse_pos/img_0657.jpg',
#  '../data_all/mouse_pos/img_0658.jpg',
#  '../data_all/mouse_pos/img_0659.jpg',
#  '../data_all/mouse_pos/img_0660.jpg',
#  '../data_all/mouse_pos/img_0661.jpg',
#  '../data_all/mouse_pos/img_0662.jpg',
#  '../data_all/mouse_pos/img_0663.jpg',
#  '../data_all/mouse_pos/img_0664.jpg',
#  '../data_all/mouse_pos/img_0665.jpg',
#  '../data_all/mouse_pos/img_0666.jpg',
#  '../data_all/mouse_pos/img_0667.jpg',
#  '../data_all/mouse_pos/img_0668.jpg',
#  '../data_all/mouse_pos/img_0669.jpg',
#  '../data_all/mouse_pos/img_0670.jpg',
#  '../data_all/mouse_pos/img_0671.jpg',
#  '../data_all/mouse_pos/img_0672.jpg',
#  '../data_all/mouse_pos/img_0673.jpg',
#  '../data_all/mouse_pos/img_0674.jpg',
#  '../data_all/mouse_pos/img_0675.jpg',
#  '../data_all/mouse_pos/img_0676.jpg',
#  '../data_all/mouse_pos/img_0677.jpg',
#  '../data_all/mouse_pos/img_0678.jpg',
#  '../data_all/mouse_pos/img_0679.jpg',
#  '../data_all/mouse_pos/img_0680.jpg',
#  '../data_all/mouse_pos/img_0681.jpg',
#  '../data_all/mouse_pos/img_0682.jpg',
#  '../data_all/mouse_pos/img_0683.jpg',
#  '../data_all/mouse_pos/img_0684.jpg',
#  '../data_all/mouse_pos/img_0685.jpg',
#  '../data_all/mouse_pos/img_0686.jpg',
#  '../data_all/mouse_pos/img_0687.jpg',
#  '../data_all/mouse_pos/img_0688.jpg',
#  '../data_all/mouse_pos/img_0689.jpg',
#  '../data_all/mouse_pos/img_0690.jpg',
#  '../data_all/mouse_pos/img_0691.jpg',
#  '../data_all/mouse_pos/img_0692.jpg',
#  '../data_all/mouse_pos/img_0693.jpg',
#  '../data_all/mouse_pos/img_0694.jpg',
#  '../data_all/mouse_pos/img_0695.jpg',
#  '../data_all/mouse_pos/img_0696.jpg',
#  '../data_all/mouse_pos/img_0697.jpg',
#  '../data_all/mouse_pos/img_0698.jpg',
#  '../data_all/mouse_pos/img_0699.jpg',
#  '../data_all/mouse_pos/img_0700.jpg',
#  '../data_all/mouse_pos/img_0701.jpg',
#  '../data_all/mouse_pos/img_0702.jpg',
#  '../data_all/mouse_pos/img_0703.jpg',
#  '../data_all/mouse_pos/img_0704.jpg',
#  '../data_all/mouse_pos/img_0705.jpg',
#  '../data_all/mouse_pos/img_0706.jpg',
#  '../data_all/mouse_pos/img_0707.jpg',
#  '../data_all/mouse_pos/img_0708.jpg',
#  '../data_all/mouse_pos/img_0709.jpg',
#  '../data_all/mouse_pos/img_0710.jpg',
#  '../data_all/mouse_pos/img_0711.jpg',
#  '../data_all/mouse_pos/img_0712.jpg',
#  '../data_all/mouse_pos/img_0713.jpg',
#  '../data_all/mouse_pos/img_0714.jpg',
#  '../data_all/mouse_pos/img_0715.jpg',
#  '../data_all/mouse_pos/img_0716.jpg',
#  '../data_all/mouse_pos/img_0717.jpg',
#  '../data_all/mouse_pos/img_0718.jpg',
#  '../data_all/mouse_pos/img_0719.jpg',
#  '../data_all/mouse_pos/img_0720.jpg',
#  '../data_all/mouse_pos/img_0721.jpg',
#  '../data_all/mouse_pos/img_0722.jpg',
#  '../data_all/mouse_pos/img_0723.jpg',
#  '../data_all/mouse_pos/img_0724.jpg',
#  '../data_all/mouse_pos/img_0725.jpg',
#  '../data_all/mouse_pos/img_0726.jpg',
#  '../data_all/mouse_pos/img_0727.jpg',
#  '../data_all/mouse_pos/img_0728.jpg',
#  '../data_all/mouse_pos/img_0729.jpg',
#  '../data_all/mouse_pos/img_0730.jpg',
#  '../data_all/mouse_pos/img_0731.jpg',
#  '../data_all/mouse_pos/img_0732.jpg',
#  '../data_all/mouse_pos/img_0733.jpg',
#  '../data_all/mouse_pos/img_0734.jpg',
#  '../data_all/mouse_pos/img_0735.jpg',
#  '../data_all/mouse_pos/img_0736.jpg',
#  '../data_all/mouse_pos/img_0737.jpg',
#  '../data_all/mouse_pos/img_0738.jpg',
#  '../data_all/mouse_pos/img_0739.jpg',
#  '../data_all/mouse_pos/img_0740.jpg',
#  '../data_all/mouse_pos/img_0741.jpg',
#  '../data_all/mouse_pos/img_0742.jpg',
#  '../data_all/mouse_pos/img_0743.jpg',
#  '../data_all/mouse_pos/img_0744.jpg',
#  '../data_all/mouse_pos/img_0745.jpg',
#  '../data_all/mouse_pos/img_0746.jpg',
#  '../data_all/mouse_pos/img_0747.jpg',
#  '../data_all/mouse_pos/img_0748.jpg',
#  '../data_all/mouse_pos/img_0749.jpg',
#  '../data_all/mouse_pos/img_0750.jpg',
#  '../data_all/mouse_pos/img_0751.jpg',
#  '../data_all/mouse_pos/img_0752.jpg',
#  '../data_all/mouse_pos/img_0753.jpg',
#  '../data_all/mouse_pos/img_0754.jpg',
#  '../data_all/mouse_pos/img_0755.jpg',
#  '../data_all/mouse_pos/img_0756.jpg',
#  '../data_all/mouse_pos/img_0757.jpg',
#  '../data_all/mouse_pos/img_0758.jpg',
#  '../data_all/mouse_pos/img_0759.jpg',
#  '../data_all/mouse_pos/img_0760.jpg',
#  '../data_all/mouse_pos/img_0761.jpg',
#  '../data_all/mouse_pos/img_0762.jpg',
#  '../data_all/mouse_pos/img_0763.jpg',
#  '../data_all/mouse_pos/img_0764.jpg',
#  '../data_all/mouse_pos/img_0765.jpg',
#  '../data_all/mouse_pos/img_0766.jpg',
#  '../data_all/mouse_pos/img_0767.jpg',
#  '../data_all/mouse_pos/img_0768.jpg',
#  '../data_all/mouse_pos/img_0769.jpg',
#  '../data_all/mouse_pos/img_0770.jpg',
#  '../data_all/mouse_pos/img_0771.jpg',
#  '../data_all/mouse_pos/img_0772.jpg',
#  '../data_all/mouse_pos/img_0773.jpg',
#  '../data_all/mouse_pos/img_0774.jpg',
#  '../data_all/mouse_pos/img_0775.jpg',
#  '../data_all/mouse_pos/img_0776.jpg',
#  '../data_all/mouse_pos/img_0777.jpg',
#  '../data_all/mouse_pos/img_0778.jpg',
#  '../data_all/mouse_pos/img_0779.jpg',
#  '../data_all/mouse_pos/img_0780.jpg',
#  '../data_all/mouse_pos/img_0781.jpg',
#  '../data_all/mouse_pos/img_0782.jpg',
#  '../data_all/mouse_pos/img_0783.jpg',
#  '../data_all/mouse_pos/img_0784.jpg',
#  '../data_all/mouse_pos/img_0785.jpg',
#  '../data_all/mouse_pos/img_0786.jpg',
#  '../data_all/mouse_pos/img_0787.jpg',
#  '../data_all/mouse_pos/img_0788.jpg',
#  '../data_all/mouse_pos/img_0789.jpg',
#  '../data_all/mouse_pos/img_0790.jpg',
#  '../data_all/mouse_pos/img_0791.jpg',
#  '../data_all/mouse_pos/img_0792.jpg',
#  '../data_all/mouse_pos/img_0793.jpg',
#  '../data_all/mouse_pos/img_0794.jpg',
#  '../data_all/mouse_pos/img_0795.jpg',
#  '../data_all/mouse_pos/img_0796.jpg',
#  '../data_all/mouse_pos/img_0797.jpg',
#  '../data_all/mouse_pos/img_0798.jpg',
#  '../data_all/mouse_pos/img_0799.jpg',
#  '../data_all/mouse_pos/img_0800.jpg',
#  '../data_all/mouse_pos/img_0801.jpg',
#  '../data_all/mouse_pos/img_0802.jpg',
#  '../data_all/mouse_pos/img_0803.jpg',
#  '../data_all/mouse_pos/img_0804.jpg',
#  '../data_all/mouse_pos/img_0805.jpg',
#  '../data_all/mouse_pos/img_0806.jpg',
#  '../data_all/mouse_pos/img_0807.jpg',
#  '../data_all/mouse_pos/img_0808.jpg',
#  '../data_all/mouse_pos/img_0809.jpg',
#  '../data_all/mouse_pos/img_0810.jpg',
#  '../data_all/mouse_pos/img_0811.jpg',
#  '../data_all/mouse_pos/img_0812.jpg',
#  '../data_all/mouse_pos/img_0813.jpg',
#  '../data_all/mouse_pos/img_0814.jpg',
#  '../data_all/mouse_pos/img_0815.jpg',
#  '../data_all/mouse_pos/img_0816.jpg',
#  '../data_all/mouse_pos/img_0817.jpg',
#  '../data_all/mouse_pos/img_0818.jpg',
#  '../data_all/mouse_pos/img_0819.jpg',
#  '../data_all/mouse_pos/img_0820.jpg',
#  '../data_all/mouse_pos/img_0821.jpg',
#  '../data_all/mouse_pos/img_0822.jpg',
#  '../data_all/mouse_pos/img_0823.jpg',
#  '../data_all/mouse_pos/img_0824.jpg',
#  '../data_all/mouse_pos/img_0825.jpg',
#  '../data_all/mouse_pos/img_0826.jpg',
#  '../data_all/mouse_pos/img_0827.jpg',
#  '../data_all/mouse_pos/img_0828.jpg',
#  '../data_all/mouse_pos/img_0829.jpg',
#  '../data_all/mouse_pos/img_0830.jpg',
#  '../data_all/mouse_pos/img_0831.jpg',
#  '../data_all/mouse_pos/img_0832.jpg',
#  '../data_all/mouse_pos/img_0833.jpg',
#  '../data_all/mouse_pos/img_0834.jpg',
#  '../data_all/mouse_pos/img_0835.jpg',
#  '../data_all/mouse_pos/img_0836.jpg',
#  '../data_all/mouse_pos/img_0837.jpg',
#  '../data_all/mouse_pos/img_0838.jpg',
#  '../data_all/mouse_pos/img_0839.jpg',
#  '../data_all/mouse_pos/img_0840.jpg',
#  '../data_all/mouse_pos/img_0841.jpg',
#  '../data_all/mouse_pos/img_0842.jpg',
#  '../data_all/mouse_pos/img_0843.jpg',
#  '../data_all/mouse_pos/img_0844.jpg',
#  '../data_all/mouse_pos/img_0845.jpg',
#  '../data_all/mouse_pos/img_0846.jpg',
#  '../data_all/mouse_pos/img_0847.jpg',
#  '../data_all/mouse_pos/img_0848.jpg',
#  '../data_all/mouse_pos/img_0849.jpg',
#  '../data_all/mouse_pos/img_0850.jpg',
#  '../data_all/mouse_pos/img_0851.jpg',
#  '../data_all/mouse_pos/img_0852.jpg',
#  '../data_all/mouse_pos/img_0853.jpg',
#  '../data_all/mouse_pos/img_0854.jpg',
#  '../data_all/mouse_pos/img_0855.jpg',
#  '../data_all/mouse_pos/img_0856.jpg',
#  '../data_all/mouse_pos/img_0857.jpg',
#  '../data_all/mouse_pos/img_0858.jpg',
#  '../data_all/mouse_pos/img_0859.jpg',
#  '../data_all/mouse_pos/img_0860.jpg',
#  '../data_all/mouse_pos/img_0861.jpg',
#  '../data_all/mouse_pos/img_0862.jpg',
#  '../data_all/mouse_pos/img_0863.jpg',
#  '../data_all/mouse_pos/img_0864.jpg',
#  '../data_all/mouse_pos/img_0865.jpg',
#  '../data_all/mouse_pos/img_0866.jpg',
#  '../data_all/mouse_pos/img_0867.jpg',
#  '../data_all/mouse_pos/img_0868.jpg',
#  '../data_all/mouse_pos/img_0869.jpg',
#  '../data_all/mouse_pos/img_0870.jpg',
#  '../data_all/mouse_pos/img_0871.jpg',
#  '../data_all/mouse_pos/img_0872.jpg',
#  '../data_all/mouse_pos/img_0873.jpg',
#  '../data_all/mouse_pos/img_0874.jpg',
#  '../data_all/mouse_pos/img_0875.jpg',
#  '../data_all/mouse_pos/img_0876.jpg',
#  '../data_all/mouse_pos/img_0877.jpg',
#  '../data_all/mouse_pos/img_0878.jpg',
#  '../data_all/mouse_pos/img_0879.jpg',
#  '../data_all/mouse_pos/img_0880.jpg',
#  '../data_all/mouse_pos/img_0881.jpg',
#  '../data_all/mouse_pos/img_0882.jpg',
#  '../data_all/mouse_pos/img_0883.jpg',
#  '../data_all/mouse_pos/img_0884.jpg',
#  '../data_all/mouse_pos/img_0885.jpg',
#  '../data_all/mouse_pos/img_0886.jpg',
#  '../data_all/mouse_pos/img_0887.jpg',
#  '../data_all/mouse_pos/img_0888.jpg',
#  '../data_all/mouse_pos/img_0889.jpg',
#  '../data_all/mouse_pos/img_0890.jpg',
#  '../data_all/mouse_pos/img_0891.jpg',
#  '../data_all/mouse_pos/img_0892.jpg',
#  '../data_all/mouse_pos/img_0893.jpg',
#  '../data_all/mouse_pos/img_0894.jpg',
#  '../data_all/mouse_pos/img_0895.jpg',
#  '../data_all/mouse_pos/img_0896.jpg',
#  '../data_all/mouse_pos/img_0897.jpg',
#  '../data_all/mouse_pos/img_0898.jpg',
#  '../data_all/mouse_pos/img_0899.jpg',
#  '../data_all/mouse_pos/img_0900.jpg',
#  '../data_all/mouse_pos/img_0901.jpg',
#  '../data_all/mouse_pos/img_0902.jpg',
#  '../data_all/mouse_pos/img_0903.jpg',
#  '../data_all/mouse_pos/img_0904.jpg',
#  '../data_all/mouse_pos/img_0905.jpg',
#  '../data_all/mouse_pos/img_0906.jpg',
#  '../data_all/mouse_pos/img_0907.jpg',
#  '../data_all/mouse_pos/img_0908.jpg',
#  '../data_all/mouse_pos/img_0909.jpg',
#  '../data_all/mouse_pos/img_0910.jpg',
#  '../data_all/mouse_pos/img_0911.jpg',
#  '../data_all/mouse_pos/img_0912.jpg',
#  '../data_all/mouse_pos/img_0913.jpg',
#  '../data_all/mouse_pos/img_0914.jpg',
#  '../data_all/mouse_pos/img_0915.jpg',
#  '../data_all/mouse_pos/img_0916.jpg',
#  '../data_all/mouse_pos/img_0917.jpg',
#  '../data_all/mouse_pos/img_0918.jpg',
#  '../data_all/mouse_pos/img_0919.jpg',
#  '../data_all/mouse_pos/img_0920.jpg',
#  '../data_all/mouse_pos/img_0921.jpg',
#  '../data_all/mouse_pos/img_0922.jpg',
#  '../data_all/mouse_pos/img_0923.jpg',
#  '../data_all/mouse_pos/img_0924.jpg',
#  '../data_all/mouse_pos/img_0925.jpg',
#  '../data_all/mouse_pos/img_0926.jpg',
#  '../data_all/mouse_pos/img_0927.jpg',
#  '../data_all/mouse_pos/img_0928.jpg',
#  '../data_all/mouse_pos/img_0929.jpg',
#  '../data_all/mouse_pos/img_0930.jpg',
#  '../data_all/mouse_pos/img_0931.jpg',
#  '../data_all/mouse_pos/img_0932.jpg',
#  '../data_all/mouse_pos/img_0933.jpg',
#  '../data_all/mouse_pos/img_0934.jpg',
#  '../data_all/mouse_pos/img_0935.jpg',
#  '../data_all/mouse_pos/img_0936.jpg',
#  '../data_all/mouse_pos/img_0937.jpg',
#  '../data_all/mouse_pos/img_0938.jpg',
#  '../data_all/mouse_pos/img_0939.jpg',
#  '../data_all/mouse_pos/img_0940.jpg',
#  '../data_all/mouse_pos/img_0941.jpg',
#  '../data_all/mouse_pos/img_0942.jpg',
#  '../data_all/mouse_pos/img_0943.jpg',
#  '../data_all/mouse_pos/img_0944.jpg',
#  '../data_all/mouse_pos/img_0945.jpg',
#  '../data_all/mouse_pos/img_0946.jpg',
#  '../data_all/mouse_pos/img_0947.jpg',
#  '../data_all/mouse_pos/img_0948.jpg',
#  '../data_all/mouse_pos/img_0949.jpg',
#  '../data_all/mouse_pos/img_0950.jpg',
#  '../data_all/mouse_pos/img_0951.jpg',
#  '../data_all/mouse_pos/img_0952.jpg',
#  '../data_all/mouse_pos/img_0953.jpg',
#  '../data_all/mouse_pos/img_0954.jpg',
#  '../data_all/mouse_pos/img_0955.jpg',
#  '../data_all/mouse_pos/img_0956.jpg',
#  '../data_all/mouse_pos/img_0957.jpg',
#  '../data_all/mouse_pos/img_0958.jpg',
#  '../data_all/mouse_pos/img_0959.jpg',
#  '../data_all/mouse_pos/img_0960.jpg',
#  '../data_all/mouse_pos/img_0961.jpg',
#  '../data_all/mouse_pos/img_0962.jpg',
#  '../data_all/mouse_pos/img_0963.jpg',
#  '../data_all/mouse_pos/img_0964.jpg',
#  '../data_all/mouse_pos/img_0965.jpg',
#  '../data_all/mouse_pos/img_0966.jpg',
#  '../data_all/mouse_pos/img_0967.jpg',
#  '../data_all/mouse_pos/img_0968.jpg',
#  '../data_all/mouse_pos/img_0969.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0971.jpg',
#  '../data_all/mouse_pos/img_0972.jpg',
#  '../data_all/mouse_pos/img_0973.jpg',
#  '../data_all/mouse_pos/img_0974.jpg',
#  '../data_all/mouse_pos/img_0975.jpg',
#  '../data_all/mouse_pos/img_0976.jpg',
#  '../data_all/mouse_pos/img_0977.jpg',
#  '../data_all/mouse_pos/img_0978.jpg',
#  '../data_all/mouse_pos/img_0979.jpg',
#  '../data_all/mouse_pos/img_0980.jpg',
#  '../data_all/mouse_pos/img_0981.jpg',
#  '../data_all/mouse_pos/img_0982.jpg',
#  '../data_all/mouse_pos/img_0983.jpg',
#  '../data_all/mouse_pos/img_0984.jpg',
#  '../data_all/mouse_pos/img_0985.jpg',
#  '../data_all/mouse_pos/img_0986.jpg',
#  '../data_all/mouse_pos/img_0987.jpg',
#  '../data_all/mouse_pos/img_0988.jpg',
#  '../data_all/mouse_pos/img_0989.jpg',
#  '../data_all/mouse_pos/img_0990.jpg',
#  '../data_all/mouse_pos/img_0991.jpg',
#  '../data_all/mouse_pos/img_0992.jpg',
#  '../data_all/mouse_pos/img_0993.jpg',
#  '../data_all/mouse_pos/img_0994.jpg',
#  '../data_all/mouse_pos/img_0995.jpg',
#  '../data_all/mouse_pos/img_0996.jpg',
#  '../data_all/mouse_pos/img_0997.jpg',
#  '../data_all/mouse_pos/img_0998.jpg',
#  '../data_all/mouse_pos/img_0999.jpg',
#  '../data_all/mouse_pos/img_1000.jpg',
#  ...]

# %%
sorted_path = pathSorting(all_path)

# %%
len(sorted_path)
# Out:
# 4555

# %%
all_path[1]
# Out:
# '../data_all/mouse_pos/img_2818.jpg'

# %%
def frame2Path(fr_num, all_path):
    fr_num=str(fr_num)    
    if len(fr_num)==1:
        fr_num = '000'+fr_num
    elif len(fr_num)==2:
        fr_num = '00'+fr_num
    elif len(fr_num)==3:
        fr_num = '0'+fr_num         
    split_path = os.path.split(all_path[0]) # an arbitrary path from all paths 
    path = os.path.join(split_path[0], "img_"+fr_num+".jpg")
    return fr_num, path

# %%
frame2Path(900, all_path)
# Out:
# ('0900', '../data_all/mouse_pos/img_0900.jpg')

# %%
def showImage(fr_num, all_path):
    fr_num, path = frame2Path(fr_num, all_path)
    img=cv2.imread(path) 
    img=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#     img = Image.open(path)
    plt.imshow(img) 
    plt.axis('off') 
    plt.show()

# %%
def showData(fr_num):
    single_df=data.iloc[[fr_num-1]]
    return single_df

# %%
fr_num = 900
fr_num, path = frame2Path(fr_num, all_path)
path
# Out:
# '../data_all/mouse_pos/img_0900.jpg'

# %%
showImage(fr_num=900, all_path=all_path)

# %%
frame2Path(20,all_path)
# Out:
# ('0020', '../data_all/mouse_pos/img_0020.jpg')

# %%
def showMarks(fr_num, data): 
    """
    This function returns two results:
    (1) image (ndarray) 
    (2) matrix of marked body parts (adarray of integer)
         [[ ear_rx, ear_ry ],
          [ ear_lx, ear_ly ],
          [ ear_cx, ear_cy ],
          [ eye_rx, eye_ry ],
          [ eye_lx, eye_ly ],
          [ eye_cx, eye_cy ],
          [   n_x ,   n_y  ]]
    If the data contains NaN value, it raises an error.
    """
    # Path 
    __, img_path=frame2Path(fr_num, all_path)
#     data_path = '../data_all/mouse_pos'
#     img_path = os.path.join(data_path,"img_0"+str(fr_num)+'.jpg')
    single_df=data.iloc[[fr_num-1]]
    if not single_df.isnull().values.any():
        # Retrieve the coordinates of the body parts to define variables
        ear_rx, ear_ry = int(single_df[['ear_r_x']].squeeze()), int(single_df[['ear_r_y']].squeeze())
        ear_lx, ear_ly = int(single_df[['ear_l_x']].squeeze()), int(single_df[['ear_l_y']].squeeze())
        eye_rx, eye_ry = int(single_df[['eye_r_x']].squeeze()), int(single_df[['eye_r_y']].squeeze())
        eye_lx, eye_ly = int(single_df[['eye_l_x']].squeeze()), int(single_df[['eye_l_y']].squeeze())
        n_x, n_y = int(single_df[['nose_x']].squeeze()), int(single_df[['nose_y']].squeeze())
        # calculate the centers
        ear_cx, ear_cy = int((ear_rx+ear_lx)/2), int((ear_ry+ear_ly)/2)
        eye_cx, eye_cy = int((eye_rx+eye_lx)/2), int((eye_ry+eye_ly)/2)
        
        all_list = np.empty((7,2))
        all_list[:] = np.nan
        all_list[0] = ear_rx, ear_ry
        all_list[1] = ear_lx, ear_ly
        all_list[2] = ear_cx, ear_cy
        all_list[3] = eye_rx, eye_ry
        all_list[4] = eye_lx, eye_ly
        all_list[5] = eye_cx, eye_cy
        all_list[6] = n_x, n_y
        
        radius = 1
        cyan=[0,255,255]
        yellow=[255,255,0]
        magenta=[255,0,255]
        font=cv2.FONT_HERSHEY_SIMPLEX
        font_scale=0.5

        img=cv2.imread(img_path) 
        img=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img_marked=img

        # plot the detected body parts
        img_marked=cv2.circle(img_marked, (ear_rx, ear_ry), radius=radius, color=cyan, thickness=5)
        img_marked=cv2.circle(img_marked, (ear_lx, ear_ly), radius=radius, color=cyan, thickness=5)
        img_marked=cv2.circle(img_marked, (eye_rx, eye_ry), radius=radius, color=yellow, thickness=5)
        img_marked=cv2.circle(img_marked, (eye_lx, eye_ly), radius=radius, color=yellow, thickness=5)
        img_marked=cv2.circle(img_marked, (n_x, n_y), radius=radius, color=magenta, thickness=5)

        # mark the center position
        img_marked=cv2.putText(img_marked, 'x', (ear_cx, ear_cy), font, font_scale, color=cyan, thickness=2)
        img_marked=cv2.putText(img_marked, 'x', (eye_cx, eye_cy), font, font_scale, color=yellow, thickness=2)
    #     return plt.imshow(img_marked), print('test')
        return img_marked, all_list.astype(int)
    else:
        return print('Check whether the data strip contains NaN values.')

# %%
fr_num=940
img, mark = showMarks(fr_num=fr_num, data=data)
plt.imshow(img)

# %%
def panCheck(img, mark):
    """
    Run this function after executing 'showMarks(fr_num, data)'
    to acquire the argurments (img, mark).
    This function simply presents the status of pan angle-wise pose. 
    An error is raised when there is NaN value in the 'mark' argument.
    """ 
    if not np.isnan(np.sum(mark)):
        ear_rx, ear_ry = mark[0]
        ear_lx, ear_ly = mark[1]
        ear_cx, ear_cy = mark[2]
        eye_rx, eye_ry = mark[3]
        eye_lx, eye_ly = mark[4]
        eye_cx, eye_cy = mark[5]
        n_x, n_y = mark[6]
        # initial check
        if ear_rx < eye_rx & eye_rx < n_x:
            print('right side clear')
        if ear_lx > eye_lx & eye_lx > n_x:
            print('left side clear')
         # Hypothesis 1: critical part is the relation between the nose and eyes
        hori_eyes=abs(eye_lx-eye_rx) # distance between the eyes (horizontal)
        n_r_dev_raw=abs(eye_rx-n_x)
        n_l_dev_raw=abs(eye_lx-n_x)
        assert n_r_dev_raw+n_l_dev_raw == hori_eyes
        # how much the nose deviates: 
        n_r_dev=n_r_dev_raw/hori_eyes #if smaller than 0.5 -> turning to the right
        n_l_dev=n_l_dev_raw/hori_eyes # if smaller than 0.5 -> turning to the left
#         print(f'|R_eye---{n_r_dev}---N---{n_l_dev}---L_eye|')
        print('|R_eye---({:.2f})---N---({:.2f})---L_eye|'.format(n_r_dev, n_l_dev))
        
        plt.imshow(img)
        plt.axis('off')
        
        # define the front face when n_r_dev and n_l_dev is larger than 0.25 
        # to be a front face, those numbers should be between 0.5 w.r.t. the center
        if (n_r_dev >0.25) & (n_l_dev>0.25):
            print('front face in terms of x-coords') # (1)
        elif n_r_dev >0.25:
            print('turning to the left') # (2)
        else:
            print('turning to the right') #(3)
        
    else:
        return print('Check whether the datastrip contains NaN values.')

# %%
panCheck(img, mark)
# Out:
# right side clear
# left side clear
# |R_eye---(0.08)---N---(0.92)---L_eye|
# turning to the right

# %%
def tiltCheck(img, mark):
    """
    Run this function after executing 'showMarks(fr_num, data)'
    to acquire the argurments (img, mark).
    This function simply presents the status of tilt angle-wise pose with marked image. 
    An error is raised when there is NaN value in the 'mark' argument.
    """ 
    if not np.isnan(np.sum(mark)):
        ear_rx, ear_ry = mark[0]
        ear_lx, ear_ly = mark[1]
        ear_cx, ear_cy = mark[2]
        eye_rx, eye_ry = mark[3]
        eye_lx, eye_ly = mark[4]
        eye_cx, eye_cy = mark[5]
        n_x, n_y = mark[6]
        
        # initial check   
        # Hypothesis 1: comparison between the distances (nose to eyes, eyes to ears) may imply important info.
        eye2ear_vert_raw=abs(eye_cy-ear_cy)
        eye2n_vert_raw=abs(eye_cy-n_y)
        ear2n_vert_raw=abs(ear_cy-n_y)
        assert eye2ear_vert_raw+eye2n_vert_raw == ear2n_vert_raw
        
        # which is larger and how much is the difference?
        eye2ear_vert_pro=round(eye2ear_vert_raw/ear2n_vert_raw,2) # round at 2nd decimal
        eye2n_vert_pro=round(eye2n_vert_raw/ear2n_vert_raw,2)
        result_m='''   
        --Ear center--
              |
            {:.2f}
              |
         -Eye center-
              |
            {:.2f}
              |
           --Nose--
        '''
        print(result_m.format(eye2ear_vert_pro, eye2n_vert_pro))
#         print('vertical distance from [Eye to Ear] : [Eye to Nose] = {:.2f} : {:.2f}'.format(eye2ear_vert_pro, eye2n_vert_pro))

        plt.imshow(img)
        plt.axis('off')
        
        # Hypothesis 2: Define the tilt-wise front face when the proportion is within 0.4 - 0.6
        if (eye2ear_vert_pro <= 0.6) &  (eye2ear_vert_pro >=0.4):
            print('front face in terms of y-coords') # (1)
        elif eye2ear_vert_pro > 0.6:
            print('tilting down')
        else:
            print('tiliting up')    
    
    else:
        return print('Check whether the datastrip contains NaN values.')

# %%
showImage(fr_num=8, all_path=all_path)

# %%
showData(fr_num=8)
# Out:
#          img_no  ear_r_x  ear_r_y  ear_l_x  ear_l_y  eye_r_x  eye_r_y  \
# 7  img_0008.jpg    262.0     85.0    376.0     96.0    267.0    197.0
#
#    eye_l_x  eye_l_y  nose_x  nose_y
# 7    331.0    203.0   280.0   280.0

# %%
fr_num = 1173
img, mark = showMarks(fr_num, data)
panCheck(img, mark)
tiltCheck(img, mark)
# Out:
# right side clear
# left side clear
# |R_eye---(0.22)---N---(0.78)---L_eye|
# turning to the right
#
#         --Ear center--
#               |
#             0.57
#               |
#          -Eye center-
#               |
#             0.43
#               |
#            --Nose--
#
# front face in terms of y-coords

# %%
def readImges(sorted_path):
    for path in sorted_path:
            img=cv2.imread(path) 
            img=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#            img = Image.open(path)
            plt.imshow(img) 
            plt.axis('off') 
            plt.show()

# %%
os.path.split(all_path[0])[0]
# Out:
# '../data_all/mouse_pos'

# %%
def readFile(all_path):
    fnum_str_list=[]
#     fnum_int_list=[]
    # read the file and sort by numbers
    for path in all_path:    
        split_path=os.path.split(path)
        fname=split_path[1]
        fnum_included_str = re.findall(r'[0-9]+', fname)
        fnum_str = fnum_included_str[0]
#         fnum_int = int(fnum_str)
        fnum_str_list.append(fnum_str)
        fnum_str_list.sort()
        
    return  [os.path.join(split_path[0], "img_"+fnum+".jpg") for fum in fnum_str_list]
#         sorted_file_path = os.path.join(split_path[0], "img_"+fnum+".jpg")
        
#         fnum_int_list.append(fnum_int)
#         tandem = list(zip(fnum_str_list,fnum_int_list))
#         tandem.sort()
        
        #

# %%
readFile(all_path)
# Out:
# ['../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  '../data_all/mouse_pos/img_0970.jpg',
#  ...]
